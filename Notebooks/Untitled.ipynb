# %%
import pandas as pd 
import numpy as np

df = pd.read_csv('/Users/ryanmedhaug/downloads/pga-tour-20102018-data/PGA_Data_Historical.csv')

df['Variable'].nunique()
# Out:
# 2081

# %%
df.head()
# Out:
#        Player Name  Season         Statistic                     Variable  \
# 0  Robert Garrigus    2010  Driving Distance  Driving Distance - (ROUNDS)
# 1     Bubba Watson    2010  Driving Distance  Driving Distance - (ROUNDS)
# 2   Dustin Johnson    2010  Driving Distance  Driving Distance - (ROUNDS)
# 3  Brett Wetterich    2010  Driving Distance  Driving Distance - (ROUNDS)
# 4      J.B. Holmes    2010  Driving Distance  Driving Distance - (ROUNDS)
#
#   Value
# 0    71
# 1    77
# 2    83
# 3    54
# 4   100

# %%
df['Statistic'].unique()
# Out:
# array(['Driving Distance', 'Driving Accuracy Percentage',
#        'Greens in Regulation Percentage', 'Putting Average',
#        'Par Breakers', 'Total Eagles', 'Total Birdies',
#        'Scoring Average (Actual)', 'Money Leaders',
#        'Sand Save Percentage', 'Par 3 Birdie or Better Leaders',
#        'Par 4 Birdie or Better Leaders', 'Par 5 Birdie or Better Leaders',
#        'Birdie or Better Conversion Percentage', 'Putts Per Round',
#        'Scoring Average', 'All-Around Ranking', 'Total Driving',
#        'Scrambling', 'Ryder Cup Points', 'PGA Championship Points',
#        'Putts made Distance', 'Top 10 Finishes', 'Non-member Earnings',
#        'Par 3 Scoring Average', 'Par 4 Scoring Average',
#        'Par 5 Scoring Average', "3-Putt Avoidance - 15-20'",
#        "3-Putt Avoidance - 20-25'", "3-Putt Avoidance > 25'",
#        'Current Par or Better Streak', "Rounds in the 60's",
#        'Money per Event Leaders', 'Eagles (Holes per)', 'Birdie Average',
# ...

# %%
df['Value'].str.replace('+','')
df
#Approach_100 = df[df['Statistic'] == "Putting from - > 10'"]
#Approach_100s = Approach_100[Approach_100['Variable'] == "Putting from - > 10' - (% MADE)"]
# Out:
#                  Player Name  Season                Statistic  \
# 0            Robert Garrigus    2010         Driving Distance
# 1               Bubba Watson    2010         Driving Distance
# 2             Dustin Johnson    2010         Driving Distance
# 3            Brett Wetterich    2010         Driving Distance
# 4                J.B. Holmes    2010         Driving Distance
# 5                  John Daly    2010         Driving Distance
# 6              Graham DeLaet    2010         Driving Distance
# 7              Angel Cabrera    2010         Driving Distance
# 8             Charles Warren    2010         Driving Distance
# 9                D.J. Trahan    2010         Driving Distance
# 10             Martin Flores    2010         Driving Distance
# 11              Rory McIlroy    2010         Driving Distance
# 12            Phil Mickelson    2010         Driving Distance
# 13            Aaron Baddeley    2010         Driving Distance
# ...

# %%
df['Value'].astype(float)
df
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-180-06b269ea94da> in <module>()
# ----> 1 df['Value'].astype(float)
#       2 df
#
# /anaconda3/lib/python3.6/site-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     116                 else:
#     117                     kwargs[new_arg_name] = new_arg_value
# --> 118             return func(*args, **kwargs)
#     119         return wrapper
#     120     return _deprecate_kwarg
#
# /anaconda3/lib/python3.6/site-packages/pandas/core/generic.py in astype(self, dtype, copy, errors, **kwargs)
#    4002         # else, only a single dtype is given
#    4003         new_data = self._data.astype(dtype=dtype, copy=copy, errors=errors,
# -> 4004                                      **kwargs)
#    4005         return self._constructor(new_data).__finalize__(self)
#    4006
#
# ...

# %%
Rors = df[df['Player Name'] == 'Dustin Johnson']
Rors_Driving_Right = Rors[Rors['Variable'] == 'Right Rough Tendency - (%)']
Rors_Driving_Right
# Out:
#             Player Name  Season             Statistic  \
# 185031   Dustin Johnson    2010  Right Rough Tendency
# 502598   Dustin Johnson    2011  Right Rough Tendency
# 810861   Dustin Johnson    2012  Right Rough Tendency
# 1109960  Dustin Johnson    2013  Right Rough Tendency
# 1403328  Dustin Johnson    2014  Right Rough Tendency
# 1701246  Dustin Johnson    2015  Right Rough Tendency
# 2002299  Dustin Johnson    2016  Right Rough Tendency
# 2309214  Dustin Johnson    2017  Right Rough Tendency
# 2616300  Dustin Johnson    2018  Right Rough Tendency
#
#                            Variable  Value
# 185031   Right Rough Tendency - (%)  18.35
# 502598   Right Rough Tendency - (%)  18.16
# 810861   Right Rough Tendency - (%)  15.72
# 1109960  Right Rough Tendency - (%)  18.12
# 1403328  Right Rough Tendency - (%)  17.28
# 1701246  Right Rough Tendency - (%)  17.00
# 2002299  Right Rough Tendency - (%)  18.19
# 2309214  Right Rough Tendency - (%)  15.57
# ...

# %%
import seaborn as sns; sns.set()
import matplotlib.pyplot as plt

#x = Rors_Driving_Accuracy['Date']
#y = Rors_Driving_Accuracy['Value']

data = Rors_Driving_Distance
sns.scatterplot(x="Season", y="Value", data=data)

# %%
df['Data'].min()
# Out:
# 266.4

# %%
df.loc[df['Data'] == 266.4]
# Out:
#     Player Name  Season         Statistic                   Variable  Value  \
# 383   Brian Gay    2010  Driving Distance  Driving Distance - (AVG.)  266.4
#
#       Data
# 383  266.4

# %%
df.loc[df['Player Name'] == 'Brian Gay']
# Out:
#         Player Name  Season         Statistic                   Variable  \
# 383       Brian Gay    2010  Driving Distance  Driving Distance - (AVG.)
# 323454    Brian Gay    2011  Driving Distance  Driving Distance - (AVG.)
# 628562    Brian Gay    2012  Driving Distance  Driving Distance - (AVG.)
# 940203    Brian Gay    2013  Driving Distance  Driving Distance - (AVG.)
# 1232162   Brian Gay    2014  Driving Distance  Driving Distance - (AVG.)
# 2127561   Brian Gay    2017  Driving Distance  Driving Distance - (AVG.)
# 2433596   Brian Gay    2018  Driving Distance  Driving Distance - (AVG.)
#
#          Value   Data
# 383      266.4  266.4
# 323454   269.8  269.8
# 628562   277.7  277.7
# 940203   275.1  275.1
# 1232162  271.6  271.6
# 2127561  278.7  278.7
# 2433596  282.9  282.9
